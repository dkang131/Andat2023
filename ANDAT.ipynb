# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller

# %%
data = pd.read_csv("C:/Users/darre/Desktop/SEM 7/AnDat/Pre Midterm/data-penumpang-kapal-bulan-maret-2020.csv")
data
# Out:
#         tanggal    pelabuhan  kapal_berangkat  kapal_tiba  penumpang_naik  \
# 0    2020-03-01  MUARA ANGKE                5          18             511
# 1    2020-03-02  MUARA ANGKE               14           5             346
# 2    2020-03-03  MUARA ANGKE                5           7             199
# 3    2020-03-04  MUARA ANGKE                6           6             302
# 4    2020-03-05  MUARA ANGKE                6           6             126
# ..          ...          ...              ...         ...             ...
# 305  2020-03-27       SABIRA                0           0               0
# 306  2020-03-28       SABIRA                0           1               0
# 307  2020-03-29       SABIRA                1           0               4
# 308  2020-03-30       SABIRA                0           1               6
# 309  2020-03-31       SABIRA                1           0               7
#
#      penumpang_turun
# 0               2212
# 1                195
# ...

# %%
df = data.copy()
df = df.set_index('tanggal')
df.index = pd.to_datetime(df.index)
df
# Out:
#               pelabuhan  kapal_berangkat  kapal_tiba  penumpang_naik  \
# tanggal
# 2020-03-01  MUARA ANGKE                5          18             511
# 2020-03-02  MUARA ANGKE               14           5             346
# 2020-03-03  MUARA ANGKE                5           7             199
# 2020-03-04  MUARA ANGKE                6           6             302
# 2020-03-05  MUARA ANGKE                6           6             126
# ...                 ...              ...         ...             ...
# 2020-03-27       SABIRA                0           0               0
# 2020-03-28       SABIRA                0           1               0
# 2020-03-29       SABIRA                1           0               4
# 2020-03-30       SABIRA                0           1               6
# 2020-03-31       SABIRA                1           0               7
#
#             penumpang_turun
# tanggal
# 2020-03-01             2212
# 2020-03-02              195
# 2020-03-03              224
# ...

# %%
plt.figure(figsize=(20, 6))  # Optional: Set the figure size
plt.plot(df.index, df['penumpang_naik'], color='b', label='Value Column')
plt.xlabel('Date')  # Optional: Add an x-axis label
plt.ylabel('Temperature')  # Optional: Add a y-axis label
plt.title('Time Series Plot')  # Optional: Add a plot title
plt.legend()  # Optional: Add a legend
plt.grid(True)  # Optional: Add grid lines
plt.show()

# %%
data_1 = pd.read_csv("C:/Users/darre/Downloads/housing.csv", sep='')
data_1
# Out:
#      0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0     0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1     0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2     0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3     0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4     0.02985   0.00   2.180  0  0.4580  6.4300  58...
# ..                                                 ...
# 500   0.06263   0.00  11.930  0  0.5730  6.5930  69...
# 501   0.04527   0.00  11.930  0  0.5730  6.1200  76...
# 502   0.06076   0.00  11.930  0  0.5730  6.9760  91...
# 503   0.10959   0.00  11.930  0  0.5730  6.7940  89...
# 504   0.04741   0.00  11.930  0  0.5730  6.0300  80...
#
# [505 rows x 1 columns]

# %%
pip install detect_delimiter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from detect_delimiter import detect
import pandas as pd

filename = "C:/Users/darre/Downloads/housing.csv"
with open(filename) as f:
    firstline = f.readline()
    delimiter = detect(firstline)

# %%
data_2 = pd.read_csv("C:/Users/darre/Downloads/housing.csv", sep = delimiter)
data_2
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_2 = pd.read_csv("C:/Users/darre/Downloads/housing.csv", sep = delimiter)
#       2 data_2
#
# ...
