# %% [markdown]
# # Heatmap

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(2)

# Generating 10x10 array between 1-50
data = np.random.randint(low=1, high=50, size=(10,10))
data
# Out:
# array([[41, 16, 46,  9, 23, 44, 19, 12, 41,  8],
#        [35, 32, 12, 22, 48, 32, 27, 21, 38, 40],
#        [ 4, 39,  5, 43, 44, 40, 39, 43, 34,  4],
#        [ 6, 25,  5, 47,  7, 32, 20, 32,  3, 17],
#        [47, 13,  5, 27, 16, 40, 47,  9, 46, 16],
#        [42, 46,  9, 18, 23, 10, 42, 47, 27, 20],
#        [33, 44, 33, 27,  9, 13, 11, 41, 35, 10],
#        [38,  7, 23,  7, 20, 19,  2,  5, 41, 18],
#        [ 7, 38, 34, 19, 21, 27, 24, 23, 44, 38],
#        [11,  9, 27, 36, 28, 33, 17, 22, 44, 30]])

# %%
plt.imshow(data)

# %%
plt.imshow(data, cmap = 'Blues') # semakin gelap semakin tinggi nilainya

# %%
plt.imshow(data, cmap='Blues')
plt.colorbar()
for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        plt.text(j, i, '%d' % data[i, j],
                 horizontalalignment='center',
                 verticalalignment='center')
        
x_labels = ['A','B','C','D','E','F','G','H','I','J']
y_labels = ['a','b','c','d','e','f','g','h','i','j']

plt.xticks(np.arange(len(x_labels)), labels=x_labels)
plt.yticks(np.arange(len(y_labels)), labels=y_labels)
# Out:
# ([<matplotlib.axis.YTick at 0x1da9edeca30>,
#   <matplotlib.axis.YTick at 0x1da9edec520>,
#   <matplotlib.axis.YTick at 0x1da9ee08f10>,
#   <matplotlib.axis.YTick at 0x1da9ef938e0>,
#   <matplotlib.axis.YTick at 0x1da9d05b5b0>,
#   <matplotlib.axis.YTick at 0x1da9ef93df0>,
#   <matplotlib.axis.YTick at 0x1da9efc6b20>,
#   <matplotlib.axis.YTick at 0x1da9efa7610>,
#   <matplotlib.axis.YTick at 0x1da9efa7e80>,
#   <matplotlib.axis.YTick at 0x1da9efc63d0>],
#  [Text(0, 0, 'a'),
#   Text(0, 1, 'b'),
#   Text(0, 2, 'c'),
#   Text(0, 3, 'd'),
#   Text(0, 4, 'e'),
#   Text(0, 5, 'f'),
#   Text(0, 6, 'g'),
#   Text(0, 7, 'h'),
#   Text(0, 8, 'i'),
#   Text(0, 9, 'j')])
